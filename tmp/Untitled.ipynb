# %%
import base64
import os
import pandas as pd
import re

from collections import defaultdict
from github import Github, Organization

from src.model import text_preprocess

# using username and password
token = os.environ.get("GITUBCTOKEN2")
# Github Enterprise with custom hostname
g = Github(base_url="https://github.ubc.ca/api/v3", login_or_token=token)
student_repos = g.search_repositories(query="students in:repo:owner/name+pushed>2020-02-09+user:MDS-2019-20")

def refresh_data():

    results = defaultdict(list)
    file_extensions = r".*(\.md|\.py|\.Rmd|.ipynb)$"
    limit = 2

    # get all content
    count = 1
    for repo in student_repos:
        print(repo)
        if "MDS-2019-20" not in repo.full_name:
            print("Not MDS 2019-20")
            continue
        contents = repo.get_contents("")
        while contents:
            file_content = contents.pop(0)
            if file_content.type == "dir":
                contents.extend(repo.get_contents(file_content.path))
            else:
    #             print(file_content)
    #             print(file_content.name)
                results["repo_name"].append(repo.name)
                results["repo_full_name"].append(repo.full_name)
                results["file_name"].append(file_content.name)
                results["size"].append(file_content.size)
                results["path"].append(file_content.path)
                results["url"].append(file_content.url)
                
                if file_content.size > 1000000 or not re.match(file_extensions, file_content.name):
                    results["encoding"].append("not read")
                    results["content"].append("not read")
                    continue
                    
                results["encoding"].append(file_content.encoding)
                results["content"].append(base64.b64decode(file_content.content))
                
        if count > limit:
            break
        else:
            count += 1

    return results

# %%
results = refresh_data()
# Out:
# Repository(full_name="yinghuag/DSCI_542_comm-arg_students")
# Not MDS 2019-20
# Repository(full_name="shaunsun/DSCI_511_prog-dsci_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_511_prog-dsci_students")
# Not MDS 2019-20
# Repository(full_name="yujul/home")
# Not MDS 2019-20
# Repository(full_name="tarini24/DSCI_531_viz-1_students")
# Not MDS 2019-20
# Repository(full_name="cpsc221/site")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_521_platforms-dsci_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_542_comm-arg_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_531_viz-1_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_551_eda-dsci_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_532_viz-2_students")
# Not MDS 2019-20
# Repository(full_name="cemsinan/DSCI_552_stat-inf-1_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_561_regr-1_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_522_dsci-workflows_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_523_data-wrangling_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_563_unsup-learn_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_513_database-data-retr_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_552_stat-inf-1_students")
# Not MDS 2019-20
# Repository(full_name="bz1013/DSCI_573_feat-model-select_students")
# Not MDS 2019-20
# Repository(full_name="hinshaws/DSCI_100_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_562_regr-2_students")
# Not MDS 2019-20
# Repository(full_name="rq1995/DSCI_522_dsci-workflows_students")
# Not MDS 2019-20
# Repository(full_name="siddfury/DSCI_532_viz-2_students")
# Not MDS 2019-20
# Repository(full_name="lang1/DSCI_562_regr-2_students")
# Not MDS 2019-20
# Repository(full_name="MDS-2019-20/DSCI_542_comm-arg_students")
# Repository(full_name="MDS-2019-20/DSCI_521_platforms-dsci_students")
# Repository(full_name="MDS-2019-20/DSCI_523_data-wrangling_students")

# %%
df = pd.DataFrame(data=results)
df
# Out:
#                             repo_name  \
# 0          DSCI_542_comm-arg_students
# 1          DSCI_542_comm-arg_students
# 2          DSCI_542_comm-arg_students
# 3          DSCI_542_comm-arg_students
# 4          DSCI_542_comm-arg_students
# ..                                ...
# 383  DSCI_523_data-wrangling_students
# 384  DSCI_523_data-wrangling_students
# 385  DSCI_523_data-wrangling_students
# 386  DSCI_523_data-wrangling_students
# 387  DSCI_523_data-wrangling_students
#
#                                    repo_full_name  \
# 0          MDS-2019-20/DSCI_542_comm-arg_students
# 1          MDS-2019-20/DSCI_542_comm-arg_students
# 2          MDS-2019-20/DSCI_542_comm-arg_students
# 3          MDS-2019-20/DSCI_542_comm-arg_students
# 4          MDS-2019-20/DSCI_542_comm-arg_students
# ..                                            ...
# 383  MDS-2019-20/DSCI_523_data-wrangling_students
# 384  MDS-2019-20/DSCI_523_data-wrangling_students
# 385  MDS-2019-20/DSCI_523_data-wrangling_students
# 386  MDS-2019-20/DSCI_523_data-wrangling_students
# 387  MDS-2019-20/DSCI_523_data-wrangling_students
#
#                             file_name     size  \
# 0                           README.md    11495
# 1    better_data_science_pipeline.png    26624
# 2           data_science_pipeline.png    31993
# 3           2019-09-11 Week 1 Lab.pdf  8104420
# 4           2019-09-18 Week 2 Lab.pdf  8075310
# ..                                ...      ...
# 383                  nycflights13.csv   402497
# 384               Exercise 4.10-1.png    58737
# 385               Exercise 4.10-2.png    60197
# 386               Exercise 4.10-3.png    59912
# 387               Exercise 4.10-4.png    60182
#
#                                                   path  \
# 0                                            README.md
# 1                 img/better_data_science_pipeline.png
# 2                        img/data_science_pipeline.png
# 3    lab presentations and solutions/2019-09-11 Wee...
# 4    lab presentations and solutions/2019-09-18 Wee...
# ..                                                 ...
# 383          labs/solutions/lab4/data/nycflights13.csv
# 384  labs/solutions/lab1/lab1_files/figure-gfm/Exer...
# 385  labs/solutions/lab1/lab1_files/figure-gfm/Exer...
# 386  labs/solutions/lab1/lab1_files/figure-gfm/Exer...
# 387  labs/solutions/lab1/lab1_files/figure-gfm/Exer...
#
#                                                    url  encoding  \
# 0    https://github.ubc.ca/api/v3/repos/MDS-2019-20...    base64
# 1    https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 2    https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 3    https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 4    https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# ..                                                 ...       ...
# 383  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 384  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 385  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 386  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 387  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
#
#                                                content
# 0    b'# DSCI 542: Communication and Argumentation\...
# 1                                             not read
# 2                                             not read
# 3                                             not read
# 4                                             not read
# ..                                                 ...
# 383                                           not read
# 384                                           not read
# 385                                           not read
# 386                                           not read
# 387                                           not read
#
# [388 rows x 8 columns]

# %%
df.loc[:,"content"]
# Out:
# 0      b'# DSCI 542: Communication and Argumentation\...
# 1                                               not read
# 2                                               not read
# 3                                               not read
# 4                                               not read
#                              ...
# 383                                             not read
# 384                                             not read
# 385                                             not read
# 386                                             not read
# 387                                             not read
# Name: content, Length: 388, dtype: object

# %%
def test(x):
    if type(x) == str:
        return "it is a string"
    else:
        return x.decode("utf-8").lower()

# %%
# df["content_clean"] = 
df.loc[:,"content"].apply(test)
# Out:
# 0      # dsci 542: communication and argumentation\n\...
# 1                                         it is a string
# 2                                         it is a string
# 3                                         it is a string
# 4                                         it is a string
#                              ...
# 383                                       it is a string
# 384                                       it is a string
# 385                                       it is a string
# 386                                       it is a string
# 387                                       it is a string
# Name: content, Length: 388, dtype: object

# %%
df.iloc[0, 8].decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-90c6812e5b8c> in <module>
# ----> 1 df.iloc[0, 8].decode("utf-8")
#
# TypeError: descriptor 'decode' requires a 'bytes' object but received a 'str'

# %%
pd.read_csv("data/2020-03-01_student-repos.csv")
# Out:
#                             repo_name  \
# 0          DSCI_542_comm-arg_students
# 1          DSCI_542_comm-arg_students
# 2          DSCI_542_comm-arg_students
# 3          DSCI_542_comm-arg_students
# 4          DSCI_542_comm-arg_students
# ...                               ...
# 2015  DSCI_524_collab-sw-dev_students
# 2016  DSCI_524_collab-sw-dev_students
# 2017  DSCI_524_collab-sw-dev_students
# 2018  DSCI_524_collab-sw-dev_students
# 2019  DSCI_524_collab-sw-dev_students
#
#                                    repo_full_name  \
# 0          MDS-2019-20/DSCI_542_comm-arg_students
# 1          MDS-2019-20/DSCI_542_comm-arg_students
# 2          MDS-2019-20/DSCI_542_comm-arg_students
# 3          MDS-2019-20/DSCI_542_comm-arg_students
# 4          MDS-2019-20/DSCI_542_comm-arg_students
# ...                                           ...
# 2015  MDS-2019-20/DSCI_524_collab-sw-dev_students
# 2016  MDS-2019-20/DSCI_524_collab-sw-dev_students
# 2017  MDS-2019-20/DSCI_524_collab-sw-dev_students
# 2018  MDS-2019-20/DSCI_524_collab-sw-dev_students
# 2019  MDS-2019-20/DSCI_524_collab-sw-dev_students
#
#                              file_name     size  \
# 0                            README.md    11495
# 1     better_data_science_pipeline.png    26624
# 2            data_science_pipeline.png    31993
# 3            2019-09-11 Week 1 Lab.pdf  8104420
# 4            2019-09-18 Week 2 Lab.pdf  8075310
# ...                                ...      ...
# 2015               delete_branches.png   327746
# 2016                 github_kanban.png   429312
# 2017              readr-milestones.png   252847
# 2018                 view_branches.png   251613
# 2019                     milestone1.md     9647
#
#                                                    path  \
# 0                                             README.md
# 1                  img/better_data_science_pipeline.png
# 2                         img/data_science_pipeline.png
# 3     lab presentations and solutions/2019-09-11 Wee...
# 4     lab presentations and solutions/2019-09-18 Wee...
# ...                                                 ...
# 2015                   lectures/img/delete_branches.png
# 2016                     lectures/img/github_kanban.png
# 2017                  lectures/img/readr-milestones.png
# 2018                     lectures/img/view_branches.png
# 2019                   release/milestone1/milestone1.md
#
#                                                     url  encoding  \
# 0     https://github.ubc.ca/api/v3/repos/MDS-2019-20...    base64
# 1     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 2     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 3     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 4     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# ...                                                 ...       ...
# 2015  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 2016  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 2017  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 2018  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 2019  https://github.ubc.ca/api/v3/repos/MDS-2019-20...    base64
#
#                                                 content  \
# 0     # dsci 542: communication and argumentation\n\...
# 1                      better_data_science_pipeline.png
# 2                             data_science_pipeline.png
# 3                             2019-09-11 Week 1 Lab.pdf
# 4                             2019-09-18 Week 2 Lab.pdf
# ...                                                 ...
# 2015                                delete_branches.png
# 2016                                  github_kanban.png
# 2017                               readr-milestones.png
# 2018                                  view_branches.png
# 2019  # dsci 524 - collaborative software developmen...
#
#                                           content_clean
# 0      dsci  communication and argumentation todo da...
# 1                          betterdatasciencepipelinepng
# 2                                datasciencepipelinepng
# 3                                          week  labpdf
# 4                                          week  labpdf
# ...                                                 ...
# 2015                                  deletebranchespng
# 2016                                    githubkanbanpng
# 2017                                 readrmilestonespng
# 2018                                    viewbranchespng
# 2019   dsci   collaborative software development pro...
#
# [2020 rows x 9 columns]
