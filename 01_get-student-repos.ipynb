# %%
# https://pygithub.readthedocs.io/en/latest/examples/Repository.html
import base64
import os
import pandas as pd
import re

from collections import defaultdict
from github import Github, Organization

# %%
# using username and password
token = os.environ.get("GITUBCTOKEN2")
# Github Enterprise with custom hostname
g = Github(base_url="https://github.ubc.ca/api/v3", login_or_token=token)

# %%
# get all student repos
student_repos = g.search_repositories(query="students in:repo:owner/name+pushed>2020-02-09+user:MDS-2019-20")
# for repo in student_repos:
#     print(repo)

# %%
results = defaultdict(list)
file_extensions = r".*(\.md|\.py|\.Rmd|.ipynb)$"
limit = 20

# get all content
count = 1
for repo in student_repos:
    print(repo)
    if "MDS-2019-20" not in repo.full_name:
        print("Not MDS 2019-20")
        continue
    contents = repo.get_contents("")
    while contents:
        file_content = contents.pop(0)
        if file_content.type == "dir":
            contents.extend(repo.get_contents(file_content.path))
        else:
#             print(file_content)
#             print(file_content.name)
            results["repo_name"].append(repo.name)
            results["repo_full_name"].append(repo.full_name)
            results["file_name"].append(file_content.name)
            results["size"].append(file_content.size)
            results["path"].append(file_content.path)
            results["url"].append(file_content.url)
            
            if file_content.size > 1000000 or not re.match(file_extensions, file_content.name):
                results["encoding"].append("not read")
                results["content"].append("not read")
                continue
                
            results["encoding"].append(file_content.encoding)
            results["content"].append(base64.b64decode(file_content.content))
            
    if count > limit:
        break
    else:
        count += 1
# Out:
# Repository(full_name="yinghuag/DSCI_542_comm-arg_students")
# Not MDS 2019-20
# Repository(full_name="shaunsun/DSCI_511_prog-dsci_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_511_prog-dsci_students")
# Not MDS 2019-20
# Repository(full_name="yujul/home")
# Not MDS 2019-20
# Repository(full_name="tarini24/DSCI_531_viz-1_students")
# Not MDS 2019-20
# Repository(full_name="cpsc221/site")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_521_platforms-dsci_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_542_comm-arg_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_531_viz-1_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_551_eda-dsci_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_532_viz-2_students")
# Not MDS 2019-20
# Repository(full_name="cemsinan/DSCI_552_stat-inf-1_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_561_regr-1_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_522_dsci-workflows_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_523_data-wrangling_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_563_unsup-learn_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_513_database-data-retr_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_552_stat-inf-1_students")
# Not MDS 2019-20
# Repository(full_name="bz1013/DSCI_573_feat-model-select_students")
# Not MDS 2019-20
# Repository(full_name="hinshaws/DSCI_100_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_562_regr-2_students")
# Not MDS 2019-20
# Repository(full_name="rq1995/DSCI_522_dsci-workflows_students")
# Not MDS 2019-20
# Repository(full_name="siddfury/DSCI_532_viz-2_students")
# Not MDS 2019-20
# Repository(full_name="lang1/DSCI_562_regr-2_students")
# Not MDS 2019-20
# Repository(full_name="MDS-2019-20/DSCI_542_comm-arg_students")
# Repository(full_name="MDS-2019-20/DSCI_521_platforms-dsci_students")
# Repository(full_name="MDS-2019-20/DSCI_523_data-wrangling_students")
# Repository(full_name="MDS-2019-20/DSCI_531_viz-1_students")
# Repository(full_name="MDS-2019-20/DSCI_532_viz-2_students")
# Repository(full_name="MDS-2019-20/DSCI_561_regr-1_students")
# Repository(full_name="MDS-2019-20/DSCI_511_prog-dsci_students")
# Repository(full_name="MDS-2019-20/DSCI_591_capstone-proj_students")
# Repository(full_name="MDS-2019-20/DSCI_562_regr-2_students")
# Repository(full_name="MDS-2019-20/DSCI_522_dsci-workflows_students")
# Repository(full_name="MDS-2019-20/DSCI_563_unsup-learn_students")
# Repository(full_name="alim1990/DSCI_553_stat-inf-2_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_524_collab-sw-dev_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_512_alg-data-struct_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_573_feat-model-select_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_541_priv-eth-sec_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_572_sup-learn-2_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_571_sup-learn-1_students")
# Not MDS 2019-20
# Repository(full_name="ubc-mds-2016/DSCI_999_made-up-course_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_525_web-cloud-comp_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_554_exper-causal-inf_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_574_spat-temp-mod_students")
# Not MDS 2019-20
# Repository(full_name="alim1990/DSCI_575_adv-mach-learn_students")
# Not MDS 2019-20
# Repository(full_name="siddfury/DSCI_512_alg-data-struct_students")
# Not MDS 2019-20
# Repository(full_name="maudulo/DSCI_513_database-data-retr_students")
# Not MDS 2019-20
# Repository(full_name="MDS-2019-20/DSCI_551_stat-prob-dsci_students")
# Repository(full_name="MDS-2019-20/DSCI_512_alg-data-struct_students")
# Repository(full_name="MDS-2019-20/DSCI_552_stat-inf-1_students")
# Repository(full_name="MDS-2019-20/DSCI_513_database-data-retr_students")
# Repository(full_name="MDS-2019-20/DSCI_571_sup-learn-1_students")
# Repository(full_name="MDS-2019-20/DSCI_573_feat-model-select_students")
# Repository(full_name="MDS-2019-20/DSCI_572_sup-learn-2_students")
# Repository(full_name="MDS-2019-20/DSCI_524_collab-sw-dev_students")
# Repository(full_name="MDS-2019-20/DSCI_574_spat-temp-mod_students")
# Repository(full_name="MDS-2019-20/DSCI_553_stat-inf-2_students")

# %%
results.keys()
# Out:
# dict_keys(['repo_name', 'repo_full_name', 'file_name', 'size', 'path', 'url', 'encoding', 'content'])

# %%
pd.DataFrame(data=results)
# Out:
#                          repo_name                            repo_full_name  \
# 0       DSCI_542_comm-arg_students    MDS-2019-20/DSCI_542_comm-arg_students
# 1       DSCI_542_comm-arg_students    MDS-2019-20/DSCI_542_comm-arg_students
# 2       DSCI_542_comm-arg_students    MDS-2019-20/DSCI_542_comm-arg_students
# 3       DSCI_542_comm-arg_students    MDS-2019-20/DSCI_542_comm-arg_students
# 4       DSCI_542_comm-arg_students    MDS-2019-20/DSCI_542_comm-arg_students
# ...                            ...                                       ...
# 1989  DSCI_553_stat-inf-2_students  MDS-2019-20/DSCI_553_stat-inf-2_students
# 1990  DSCI_553_stat-inf-2_students  MDS-2019-20/DSCI_553_stat-inf-2_students
# 1991  DSCI_553_stat-inf-2_students  MDS-2019-20/DSCI_553_stat-inf-2_students
# 1992  DSCI_553_stat-inf-2_students  MDS-2019-20/DSCI_553_stat-inf-2_students
# 1993  DSCI_553_stat-inf-2_students  MDS-2019-20/DSCI_553_stat-inf-2_students
#
#                              file_name     size  \
# 0                            README.md    11495
# 1     better_data_science_pipeline.png    26624
# 2            data_science_pipeline.png    31993
# 3            2019-09-11 Week 1 Lab.pdf  8104420
# 4            2019-09-18 Week 2 Lab.pdf  8075310
# ...                                ...      ...
# 1989                         lec1.html   327687
# 1990     o-ring-erosion-or-blowby.data      140
# 1991                        act2.ipynb    28719
# 1992                co2_weekly_mlo.txt   183645
# 1993                         lec2.html   544095
#
#                                                    path  \
# 0                                             README.md
# 1                  img/better_data_science_pipeline.png
# 2                         img/data_science_pipeline.png
# 3     lab presentations and solutions/2019-09-11 Wee...
# 4     lab presentations and solutions/2019-09-18 Wee...
# ...                                                 ...
# 1989                             release/lec1/lec1.html
# 1990         release/lec1/o-ring-erosion-or-blowby.data
# 1991                            release/lec2/act2.ipynb
# 1992                    release/lec2/co2_weekly_mlo.txt
# 1993                             release/lec2/lec2.html
#
#                                                     url  encoding  \
# 0     https://github.ubc.ca/api/v3/repos/MDS-2019-20...    base64
# 1     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 2     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 3     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 4     https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# ...                                                 ...       ...
# 1989  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 1990  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 1991  https://github.ubc.ca/api/v3/repos/MDS-2019-20...    base64
# 1992  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
# 1993  https://github.ubc.ca/api/v3/repos/MDS-2019-20...  not read
#
#                                                 content
# 0     b'# DSCI 542: Communication and Argumentation\...
# 1                                              not read
# 2                                              not read
# 3                                              not read
# 4                                              not read
# ...                                                 ...
# 1989                                           not read
# 1990                                           not read
# 1991  b'{\n "cells": [\n  {\n   "cell_type": "markdo...
# 1992                                           not read
# 1993                                           not read
#
# [1994 rows x 8 columns]

# %%
pd.DataFrame(data=results).to_csv("data/2020-02-27_student-repos.csv")
